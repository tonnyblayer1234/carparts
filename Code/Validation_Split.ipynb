# %% [markdown]
# ## Mount Google Drive locally

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Path to source and destination folder
#
# - You should have created a validation image folder before moving further.

# %%
import os

# Provide the source folder
src_folder = "/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train"
# Provide the destination folder
dest_folder = "/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Test"

# %% [markdown]
# ## List sub-folders

# %%
# Find all subfolders in the source folder src_folder
directory_contents = os.listdir(src_folder)
print('directory_contents: ', directory_contents)

# Append the path of the src_folder with the sub-folders
sub_folders = []
for item in directory_contents:
  if os.path.isdir(os.path.join(src_folder,item)):
    sub_folders.append(item)
print('sub_folders: ', sub_folders)
# Out:
# directory_contents:  ['WINDOW REGULATOR', 'SPOILER', 'RADIO', 'BATTERY']
# sub_folders:  ['WINDOW REGULATOR', 'SPOILER', 'RADIO', 'BATTERY']

# %% [markdown]
# # Create duplicate folder structure

# %%
# Create the same folder structure in destination
for folder_name in sub_folders:
  os.mkdir(os.path.join(dest_folder,folder_name))

# %% [markdown]
# ## List the files

# %%
# List full paths of all images in each category/sub-folder
list_files = []
# Find all the files, note that you have to change it to tif if that is the extension
for folder_name in directory_contents:
  files_list = [_ for _ in os.listdir(os.path.join(src_folder, folder_name))]
  # Create the list with full path
  full_path_files_list = []
  for file_name in files_list:
    full_path_files_list.append(os.path.join(src_folder, folder_name, file_name))
  list_files.append(full_path_files_list)
print(list_files[1])
# Out:
# ['/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/013.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/030.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/019.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/004.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/012.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/026.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/011.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/003.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/017.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/023.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/006.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/020.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/018.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/027.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/029.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/022.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/021.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/014.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/015.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/005.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/024.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/028.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/001.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/016.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/051.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/063.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/045.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/044.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/050.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/055.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/059.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/054.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/058.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/040.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/034.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/052.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/061.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/038.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/039.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/056.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/062.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/037.jpg', '/content/drive/MyDrive/AIClub_AP_Vineeth_Adimulapu/Project/Datasets/Train/SPOILER/032.jpg',  ...

# %% [markdown]
# ## Move x% of files

# %%
import random

# Specify the fraction
#this is the splitting percentage. 10% will be sent to validation
x = 10

for files_list in list_files:
  # length of the list
  list_len = len(files_list)
  # length of x%
  frac_len = int(list_len * (x/100))
  # select x% of files
  files_to_move = random.sample(files_list, frac_len)
  for single_file in files_to_move:
    # extract the sub-string with subfolder/category and file name
    subfolder_file = '/'.join(single_file.split('/')[-2:])
    # destination path
    dst_folder = os.path.join(dest_folder, subfolder_file)
    # Move the file
    os.replace(single_file, dst_folder)

# %%
for folder_name in sub_folders:
  print(folder_name, len(os.listdir(os.path.join(dest_folder,folder_name))))
# Out:
# WINDOW REGULATOR 16
# SPOILER 16
# RADIO 17
# BATTERY 16
